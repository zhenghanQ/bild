# %%
from nilearn import plotting
% matplotlib inline

# %%
stat = '/om/project/bild/Analysis/task_openfmri/openfmri/first_level/output_dir/model01/task002/BILDC3302/zstats/mni/zstat01.nii.gz'
anat_template = '/om/user/ysa/OASIS-30_Atropos_template_in_MNI152_2mm.nii.gz'
plotting.plot_stat_map(stat, bg_img=anat_template, threshold=4,)
